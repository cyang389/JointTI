# %%
import numpy as np
import pandas as pd
from model.autoencoder import AutoEncoder
from model.vae import aligned_vae, vae, ae_from_vae
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
import diffusion_dist as diff
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from dataset import *
import scipy
import torchvision

# %% [markdown]
# # AE

# %%
batch = 1024
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])
train_dataset = torchvision.datasets.MNIST(
    root = './torch_dataset', train = True, download = True, transform = transform
)
# load training data and test data
train_loader = torch.utils.data.DataLoader(
    dataset = train_dataset, batch_size = batch, shuffle = True, num_workers = 4, pin_memory = True
)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# subset first 512 images for training
dataiter = iter(train_loader)
images, labels = dataiter.next()
images.shape
# Out:
# torch.Size([1024, 1, 28, 28])

# %%
mnist_dataset = images.squeeze().reshape(batch, 28*28)
mnist_train = DataLoader(mnist_dataset, shuffle = True, batch_size = 1024)
mnist_test = DataLoader(mnist_dataset, shuffle = True, batch_size = 1024)

# %%
def train_mnist(model, data_loader, beta = 0.01):
    model.train()

    total_loss = 0
    total_loss_recon_rna = 0
    total_loss_kl = 0
    for count, data in enumerate(data_loader):
        optimizer.zero_grad()
        batch_rna = data.to(device)
        # print(batch_rna.shape)
        recon_rna, mu, logvar = model(batch_rna)
        # print(mu.shape)
        # print(z.shape)
        loss = F.mse_loss(batch_rna, recon_rna)

        total_loss += loss
        loss.backward()

        optimizer.step()
    
    return total_loss # / (count + 1) / data_loader.batch_size

# %%
def test_mnist(model, data_loader):
    model.eval()
    
    for data in data_loader:
        recon_rna, z, logvar = model(data.to(device))
    z = z.detach().cpu().numpy()
    loss_rna = F.mse_loss(data.to(device), recon_rna).item()

    print("reconstruction loss", loss_rna)
    
    for j in np.arange(data.shape[0]):
        print("original difference between sample")
        print(torch.norm(data[0,:] - data[j,:]))
        print("reconstruction difference between samples")
        print(torch.norm(recon_rna[0,:] - recon_rna[j,:]))

    
    return z, loss_rna, recon_rna

# %%
model_ae = ae_from_vae(in_channels = mnist_dataset.shape[1], latent_channels = 8, layer1_channels = 128, layer2_channels = 64).to(device)
optimizer = torch.optim.Adam(model_ae.parameters(), lr=1e-2, weight_decay=0.01)

for epoch in range(0, 101):
    loss = train_mnist(model_ae, data_loader = mnist_train, beta=0.5)
    if epoch % 10 == 0:
        log = "Epoch: {:03d}, Total loss: {:.5f}"
        print(log.format(epoch, loss))
        # print(mu)
# Out:
# Epoch: 000, Total loss: 0.11694
# Epoch: 010, Total loss: 0.08930
# Epoch: 020, Total loss: 0.07811
# Epoch: 030, Total loss: 0.07953
# Epoch: 040, Total loss: 0.08028
# Epoch: 050, Total loss: 0.07959
# Epoch: 060, Total loss: 0.07912
# Epoch: 070, Total loss: 0.07907
# Epoch: 080, Total loss: 0.07912
# Epoch: 090, Total loss: 0.07929
# Epoch: 100, Total loss: 0.07940

# %%
z, loss_val, recon_mnist = test_mnist(ae_from_vae, mnist_test)
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot()
ax.scatter(z[:,0], z[:,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c6ecb0258ced> in <module>
# ----> 1 z, loss_val, recon_mnist = test_mnist(ae_from_vae, mnist_test)
#       2 fig = plt.figure(figsize = (20,10))
#       3 ax = fig.add_subplot()
#       4 ax.scatter(z[:,0], z[:,1])
#       5 plt.show()
#
# <ipython-input-13-719a8f64a8ca> in test_mnist(model, data_loader)
#       1 def test_mnist(model, data_loader):
# ----> 2     model.eval()
#       3
#       4     for data in data_loader:
#       5         recon_rna, z, logvar = model(data.to(device))
#
# TypeError: eval() missing 1 required positional argument: 'self'

# %% [markdown]
# # Simple realization

# %%
batch = 1024
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])
train_dataset = torchvision.datasets.MNIST(
    root = './torch_dataset', train = True, download = True, transform = transform
)
# load training data and test data
train_loader = torch.utils.data.DataLoader(
    dataset = train_dataset, batch_size = batch, shuffle = True, num_workers = 4, pin_memory = True
)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# subset first 512 images for training
dataiter = iter(train_loader)
images, labels = dataiter.next()
images.shape
# Out:
# torch.Size([1024, 1, 28, 28])

# %%
mnist_dataset = images.squeeze().reshape(batch, 28*28)
mnist_train = DataLoader(mnist_dataset, shuffle = True, batch_size = 1024)
mnist_test = DataLoader(mnist_dataset, shuffle = True, batch_size = 1024)

# %%
def elbo(recon_rna, rna, z, logvar, mu, beta=0.01):
    loss_recon_rna = F.mse_loss(rna, recon_rna)

    loss_kl = beta * 0.5 * torch.sum(- logvar + torch.exp(logvar) + mu * mu - 1)

    loss = loss_recon_rna + loss_kl
    return loss, loss_recon_rna, loss_kl

# %%
def train_mnist(model, data_loader, beta = 0.01):
    model.train()

    total_loss = 0
    total_loss_recon_rna = 0
    total_loss_kl = 0
    for data in data_loader:
        optimizer.zero_grad()
        batch_rna = data.to(device)
        # print(batch_rna.shape)
        recon_rna, z, mu, logvar = model(batch_rna)
        # print(mu.shape)
        # print(z.shape)
        loss = elbo(recon_rna, batch_rna, z, logvar, mu, beta = beta)
        total_loss += loss[0]
        total_loss_recon_rna += loss[1]
        total_loss_kl += loss[2]
        current_loss = loss[0]
        current_loss.backward()
        optimizer.step()
    
    scalar = data_loader.batch_size / batch
    return total_loss.item() * scalar, total_loss_recon_rna.item() * scalar, total_loss_kl.item() * scalar, mu

# %%
def test_mnist(model, data_loader):
    model.eval()
    
    for data in data_loader:
        recon_rna, z, mu, logvar = model(data.to(device))
    z = z.detach().cpu().numpy()
    loss_rna = F.mse_loss(data.to(device), recon_rna).item()

    print("reconstruction loss", loss_rna)
    
    for j in np.arange(data.shape[0]):
        print("original difference between sample")
        print(torch.norm(data[0,:] - data[j,:]))
        print("reconstruction difference between samples")
        print(torch.norm(recon_rna[0,:] - recon_rna[j,:]))

    
    return z, loss_rna, recon_rna

# %%
model_vae = vae(in_channels = mnist_dataset.shape[1], latent_channels = 8, layer1_channels = 128, layer2_channels = 64).to(device)
optimizer = torch.optim.Adam(model_vae.parameters(), lr=5e-5, weight_decay=0.01)

for epoch in range(0, 101):
    loss, loss_mse, loss_kl, mu = train_mnist(model_vae, data_loader = mnist_train, beta=0.5)
    if epoch % 10 == 0:
        log = "Epoch: {:03d}, Total loss: {:.5f}, Recon RNA loss: {:.5f}, KL loss: {:.5f}"
        print(log.format(epoch, loss, loss_mse, loss_kl))
        # print(mu)
# Out:
# Epoch: 000, Total loss: 0.20386, Recon RNA loss: 0.17213, KL loss: 0.03173
# Epoch: 010, Total loss: 0.09643, Recon RNA loss: 0.07039, KL loss: 0.02603
# Epoch: 020, Total loss: 0.19672, Recon RNA loss: 0.16921, KL loss: 0.02751
# Epoch: 030, Total loss: 0.13051, Recon RNA loss: 0.11009, KL loss: 0.02042
# Epoch: 040, Total loss: 0.09200, Recon RNA loss: 0.07257, KL loss: 0.01943
# Epoch: 050, Total loss: 0.13117, Recon RNA loss: 0.11293, KL loss: 0.01824
# Epoch: 060, Total loss: 0.08047, Recon RNA loss: 0.06335, KL loss: 0.01712
# Epoch: 070, Total loss: 0.15125, Recon RNA loss: 0.13862, KL loss: 0.01263
# Epoch: 080, Total loss: 0.12974, Recon RNA loss: 0.11973, KL loss: 0.01002
# Epoch: 090, Total loss: 0.15942, Recon RNA loss: 0.15259, KL loss: 0.00683
# Epoch: 100, Total loss: 0.07070, Recon RNA loss: 0.05095, KL loss: 0.01975

# %%
z, loss_val, recon_mnist = test_mnist(model_vae, mnist_test)
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot()
ax.scatter(z[:,0], z[:,1])
plt.show()
# Out:
# reconstruction loss 0.11411520838737488
# original difference between sample
# tensor(0.)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0837)
# reconstruction difference between samples
# tensor(0.0737, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0550)
# reconstruction difference between samples
# tensor(0.0547, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2666)
# reconstruction difference between samples
# tensor(0.0416, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7354)
# reconstruction difference between samples
# tensor(0.0580, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9618)
# reconstruction difference between samples
# tensor(0.0771, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5319)
# reconstruction difference between samples
# tensor(0.0420, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7930)
# reconstruction difference between samples
# tensor(0.0516, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.8879)
# reconstruction difference between samples
# tensor(0.0957, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.2292)
# reconstruction difference between samples
# tensor(0.0666, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3789)
# reconstruction difference between samples
# tensor(0.0728, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1437)
# reconstruction difference between samples
# tensor(0.0392, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5108)
# reconstruction difference between samples
# tensor(0.1001, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9868)
# reconstruction difference between samples
# tensor(0.0499, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3647)
# reconstruction difference between samples
# tensor(0.0692, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5501)
# reconstruction difference between samples
# tensor(0.0678, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.8367)
# reconstruction difference between samples
# tensor(0.0360, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4195)
# reconstruction difference between samples
# tensor(0.0546, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.0636)
# reconstruction difference between samples
# tensor(0.0460, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0174)
# reconstruction difference between samples
# tensor(0.0724, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6407)
# reconstruction difference between samples
# tensor(0.0419, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7186)
# reconstruction difference between samples
# tensor(0.0251, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(13.4222)
# reconstruction difference between samples
# tensor(0.1311, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7097)
# reconstruction difference between samples
# tensor(0.0558, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4412)
# reconstruction difference between samples
# tensor(0.0719, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.0025)
# reconstruction difference between samples
# tensor(0.0266, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9967)
# reconstruction difference between samples
# tensor(0.0896, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1708)
# reconstruction difference between samples
# tensor(0.0652, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9279)
# reconstruction difference between samples
# tensor(0.0327, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5210)
# reconstruction difference between samples
# tensor(0.0680, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6768)
# reconstruction difference between samples
# tensor(0.0515, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.2071)
# reconstruction difference between samples
# tensor(0.0622, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(6.4056)
# reconstruction difference between samples
# tensor(0.0630, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3422)
# reconstruction difference between samples
# tensor(0.0688, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1862)
# reconstruction difference between samples
# tensor(0.0452, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8173)
# reconstruction difference between samples
# tensor(0.0542, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6723)
# reconstruction difference between samples
# tensor(0.0334, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.3758)
# reconstruction difference between samples
# tensor(0.0368, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5489)
# reconstruction difference between samples
# tensor(0.0310, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7143)
# reconstruction difference between samples
# tensor(0.0479, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.7342)
# reconstruction difference between samples
# tensor(0.0257, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5799)
# reconstruction difference between samples
# tensor(0.0445, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5151)
# reconstruction difference between samples
# tensor(0.0556, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5742)
# reconstruction difference between samples
# tensor(0.0461, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7876)
# reconstruction difference between samples
# tensor(0.0650, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7357)
# reconstruction difference between samples
# tensor(0.0495, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9680)
# reconstruction difference between samples
# tensor(0.0810, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5820)
# reconstruction difference between samples
# tensor(0.0547, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5406)
# reconstruction difference between samples
# tensor(0.0478, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1324)
# reconstruction difference between samples
# tensor(0.0708, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9824)
# reconstruction difference between samples
# tensor(0.0481, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9644)
# reconstruction difference between samples
# tensor(0.0711, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1114)
# reconstruction difference between samples
# tensor(0.0494, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.4405)
# reconstruction difference between samples
# tensor(0.0751, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(5.9763)
# reconstruction difference between samples
# tensor(0.0322, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6875)
# reconstruction difference between samples
# tensor(0.0277, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.3681)
# reconstruction difference between samples
# tensor(0.0787, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6481)
# reconstruction difference between samples
# tensor(0.0710, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7551)
# reconstruction difference between samples
# tensor(0.0545, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8786)
# reconstruction difference between samples
# tensor(0.0616, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5128)
# reconstruction difference between samples
# tensor(0.0492, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3178)
# reconstruction difference between samples
# tensor(0.0531, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1072)
# reconstruction difference between samples
# tensor(0.0429, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.3451)
# reconstruction difference between samples
# tensor(0.0443, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1944)
# reconstruction difference between samples
# tensor(0.0525, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3120)
# reconstruction difference between samples
# tensor(0.0457, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0991)
# reconstruction difference between samples
# tensor(0.0367, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5385)
# reconstruction difference between samples
# tensor(0.0647, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.8063)
# reconstruction difference between samples
# tensor(0.0256, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2536)
# reconstruction difference between samples
# tensor(0.0586, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0664)
# reconstruction difference between samples
# tensor(0.0765, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4430)
# reconstruction difference between samples
# tensor(0.0687, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7453)
# reconstruction difference between samples
# tensor(0.0700, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2297)
# reconstruction difference between samples
# tensor(0.0598, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5157)
# reconstruction difference between samples
# tensor(0.0491, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5416)
# reconstruction difference between samples
# tensor(0.0519, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9051)
# reconstruction difference between samples
# tensor(0.0828, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5689)
# reconstruction difference between samples
# tensor(0.0736, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2507)
# reconstruction difference between samples
# tensor(0.0641, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.6964)
# reconstruction difference between samples
# tensor(0.0499, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4662)
# reconstruction difference between samples
# tensor(0.0407, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4213)
# reconstruction difference between samples
# tensor(0.0501, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4117)
# reconstruction difference between samples
# tensor(0.0358, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0886)
# reconstruction difference between samples
# tensor(0.0746, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1920)
# reconstruction difference between samples
# tensor(0.0667, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0796)
# reconstruction difference between samples
# tensor(0.0415, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1770)
# reconstruction difference between samples
# tensor(0.0531, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1971)
# reconstruction difference between samples
# tensor(0.0394, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8327)
# reconstruction difference between samples
# tensor(0.0489, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4777)
# reconstruction difference between samples
# tensor(0.0334, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8942)
# reconstruction difference between samples
# tensor(0.0612, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4428)
# reconstruction difference between samples
# tensor(0.0390, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.6333)
# reconstruction difference between samples
# tensor(0.0393, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0598)
# reconstruction difference between samples
# tensor(0.0448, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.7218)
# reconstruction difference between samples
# tensor(0.0152, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4969)
# reconstruction difference between samples
# tensor(0.0685, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3259)
# reconstruction difference between samples
# tensor(0.0529, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7655)
# reconstruction difference between samples
# tensor(0.0448, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3285)
# reconstruction difference between samples
# tensor(0.0528, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.9797)
# reconstruction difference between samples
# tensor(0.0397, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5265)
# reconstruction difference between samples
# tensor(0.0494, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2345)
# reconstruction difference between samples
# tensor(0.0778, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1499)
# reconstruction difference between samples
# tensor(0.0443, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8673)
# reconstruction difference between samples
# tensor(0.0438, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8350)
# reconstruction difference between samples
# tensor(0.0773, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6623)
# reconstruction difference between samples
# tensor(0.0662, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3574)
# reconstruction difference between samples
# tensor(0.0505, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2686)
# reconstruction difference between samples
# tensor(0.0412, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5880)
# reconstruction difference between samples
# tensor(0.0704, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9349)
# reconstruction difference between samples
# tensor(0.0616, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5244)
# reconstruction difference between samples
# tensor(0.0508, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9911)
# reconstruction difference between samples
# tensor(0.0829, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9808)
# reconstruction difference between samples
# tensor(0.0888, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3687)
# reconstruction difference between samples
# tensor(0.0381, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1608)
# reconstruction difference between samples
# tensor(0.0458, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9256)
# reconstruction difference between samples
# tensor(0.0525, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8756)
# reconstruction difference between samples
# tensor(0.0604, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3218)
# reconstruction difference between samples
# tensor(0.0677, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9901)
# reconstruction difference between samples
# tensor(0.0540, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0829)
# reconstruction difference between samples
# tensor(0.0458, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2456)
# reconstruction difference between samples
# tensor(0.0511, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.7994)
# reconstruction difference between samples
# tensor(0.0691, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.4496)
# reconstruction difference between samples
# tensor(0.0285, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.2442)
# reconstruction difference between samples
# tensor(0.0399, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8608)
# reconstruction difference between samples
# tensor(0.0470, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8642)
# reconstruction difference between samples
# tensor(0.0615, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0315)
# reconstruction difference between samples
# tensor(0.0372, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4246)
# reconstruction difference between samples
# tensor(0.0343, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9386)
# reconstruction difference between samples
# tensor(0.0601, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0932)
# reconstruction difference between samples
# tensor(0.0496, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9933)
# reconstruction difference between samples
# tensor(0.0597, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.7000)
# reconstruction difference between samples
# tensor(0.0182, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4580)
# reconstruction difference between samples
# tensor(0.0521, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1451)
# reconstruction difference between samples
# tensor(0.0859, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.5726)
# reconstruction difference between samples
# tensor(0.0599, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6347)
# reconstruction difference between samples
# tensor(0.0462, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8150)
# reconstruction difference between samples
# tensor(0.0722, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9488)
# reconstruction difference between samples
# tensor(0.0675, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.3680)
# reconstruction difference between samples
# tensor(0.0476, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7132)
# reconstruction difference between samples
# tensor(0.0594, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3738)
# reconstruction difference between samples
# tensor(0.0663, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4584)
# reconstruction difference between samples
# tensor(0.0389, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4113)
# reconstruction difference between samples
# tensor(0.0374, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7542)
# reconstruction difference between samples
# tensor(0.0682, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4804)
# reconstruction difference between samples
# tensor(0.0908, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4776)
# reconstruction difference between samples
# tensor(0.0552, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4588)
# reconstruction difference between samples
# tensor(0.0878, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8088)
# reconstruction difference between samples
# tensor(0.0375, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0551)
# reconstruction difference between samples
# tensor(0.0557, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9972)
# reconstruction difference between samples
# tensor(0.0500, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5739)
# reconstruction difference between samples
# tensor(0.0460, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3530)
# reconstruction difference between samples
# tensor(0.0580, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4956)
# reconstruction difference between samples
# tensor(0.0463, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9032)
# reconstruction difference between samples
# tensor(0.0893, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(6.6396)
# reconstruction difference between samples
# tensor(0.0316, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.1967)
# reconstruction difference between samples
# tensor(0.0801, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2465)
# reconstruction difference between samples
# tensor(0.0772, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7844)
# reconstruction difference between samples
# tensor(0.0531, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9519)
# reconstruction difference between samples
# tensor(0.0454, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9898)
# reconstruction difference between samples
# tensor(0.0869, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6868)
# reconstruction difference between samples
# tensor(0.0468, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3247)
# reconstruction difference between samples
# tensor(0.0427, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.7171)
# reconstruction difference between samples
# tensor(0.0374, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.2327)
# reconstruction difference between samples
# tensor(0.0759, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4540)
# reconstruction difference between samples
# tensor(0.0685, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8090)
# reconstruction difference between samples
# tensor(0.0442, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1283)
# reconstruction difference between samples
# tensor(0.0919, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7519)
# reconstruction difference between samples
# tensor(0.0430, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0805)
# reconstruction difference between samples
# tensor(0.0511, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0656)
# reconstruction difference between samples
# tensor(0.0491, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.1383)
# reconstruction difference between samples
# tensor(0.0420, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7946)
# reconstruction difference between samples
# tensor(0.0775, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.5465)
# reconstruction difference between samples
# tensor(0.0857, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7383)
# reconstruction difference between samples
# tensor(0.0731, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5688)
# reconstruction difference between samples
# tensor(0.0532, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3372)
# reconstruction difference between samples
# tensor(0.0810, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(6.5398)
# reconstruction difference between samples
# tensor(0.0253, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6529)
# reconstruction difference between samples
# tensor(0.0669, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7350)
# reconstruction difference between samples
# tensor(0.0401, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9051)
# reconstruction difference between samples
# tensor(0.0618, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0624)
# reconstruction difference between samples
# tensor(0.0320, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.3962)
# reconstruction difference between samples
# tensor(0.0517, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7851)
# reconstruction difference between samples
# tensor(0.0493, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8810)
# reconstruction difference between samples
# tensor(0.0537, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.8741)
# reconstruction difference between samples
# tensor(0.1140, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8481)
# reconstruction difference between samples
# tensor(0.0652, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9572)
# reconstruction difference between samples
# tensor(0.0651, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.1588)
# reconstruction difference between samples
# tensor(0.0846, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.2048)
# reconstruction difference between samples
# tensor(0.0673, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2250)
# reconstruction difference between samples
# tensor(0.0493, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9803)
# reconstruction difference between samples
# tensor(0.0450, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.8612)
# reconstruction difference between samples
# tensor(0.1065, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6170)
# reconstruction difference between samples
# tensor(0.0198, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3120)
# reconstruction difference between samples
# tensor(0.0543, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0457)
# reconstruction difference between samples
# tensor(0.0537, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.9744)
# reconstruction difference between samples
# tensor(0.0750, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1654)
# reconstruction difference between samples
# tensor(0.0267, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8726)
# reconstruction difference between samples
# tensor(0.0850, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4983)
# reconstruction difference between samples
# tensor(0.0359, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.6566)
# reconstruction difference between samples
# tensor(0.0244, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.4006)
# reconstruction difference between samples
# tensor(0.0981, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.2759)
# reconstruction difference between samples
# tensor(0.0423, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0128)
# reconstruction difference between samples
# tensor(0.0438, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6659)
# reconstruction difference between samples
# tensor(0.0639, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4455)
# reconstruction difference between samples
# tensor(0.0867, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4091)
# reconstruction difference between samples
# tensor(0.0486, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3422)
# reconstruction difference between samples
# tensor(0.0400, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2676)
# reconstruction difference between samples
# tensor(0.0388, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8164)
# reconstruction difference between samples
# tensor(0.1076, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(5.4595)
# reconstruction difference between samples
# tensor(0.0390, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7591)
# reconstruction difference between samples
# tensor(0.0583, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6107)
# reconstruction difference between samples
# tensor(0.0465, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0070)
# reconstruction difference between samples
# tensor(0.0508, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6063)
# reconstruction difference between samples
# tensor(0.0419, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4313)
# reconstruction difference between samples
# tensor(0.0697, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7134)
# reconstruction difference between samples
# tensor(0.0624, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3100)
# reconstruction difference between samples
# tensor(0.0392, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5958)
# reconstruction difference between samples
# tensor(0.0462, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.7947)
# reconstruction difference between samples
# tensor(0.0515, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6762)
# reconstruction difference between samples
# tensor(0.0365, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.8318)
# reconstruction difference between samples
# tensor(0.0370, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0484)
# reconstruction difference between samples
# tensor(0.0509, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9457)
# reconstruction difference between samples
# tensor(0.0304, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.8030)
# reconstruction difference between samples
# tensor(0.0583, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9106)
# reconstruction difference between samples
# tensor(0.0728, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3952)
# reconstruction difference between samples
# tensor(0.0300, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5420)
# reconstruction difference between samples
# tensor(0.0647, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3355)
# reconstruction difference between samples
# tensor(0.0393, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0135)
# reconstruction difference between samples
# tensor(0.0425, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8238)
# reconstruction difference between samples
# tensor(0.0312, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5021)
# reconstruction difference between samples
# tensor(0.0768, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3658)
# reconstruction difference between samples
# tensor(0.0387, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.2839)
# reconstruction difference between samples
# tensor(0.0367, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0668)
# reconstruction difference between samples
# tensor(0.0449, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1628)
# reconstruction difference between samples
# tensor(0.0689, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2463)
# reconstruction difference between samples
# tensor(0.0397, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.9835)
# reconstruction difference between samples
# tensor(0.0578, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.8343)
# reconstruction difference between samples
# tensor(0.0243, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5191)
# reconstruction difference between samples
# tensor(0.0432, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5167)
# reconstruction difference between samples
# tensor(0.0368, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.3212)
# reconstruction difference between samples
# tensor(0.0128, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3724)
# reconstruction difference between samples
# tensor(0.0680, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4265)
# reconstruction difference between samples
# tensor(0.0416, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2538)
# reconstruction difference between samples
# tensor(0.0324, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.6209)
# reconstruction difference between samples
# tensor(0.0561, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1364)
# reconstruction difference between samples
# tensor(0.0714, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6387)
# reconstruction difference between samples
# tensor(0.0663, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2120)
# reconstruction difference between samples
# tensor(0.0625, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1707)
# reconstruction difference between samples
# tensor(0.0258, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7196)
# reconstruction difference between samples
# tensor(0.0732, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8394)
# reconstruction difference between samples
# tensor(0.0661, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2076)
# reconstruction difference between samples
# tensor(0.0574, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(6.9553)
# reconstruction difference between samples
# tensor(0.0483, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.5746)
# reconstruction difference between samples
# tensor(0.0461, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1874)
# reconstruction difference between samples
# tensor(0.0586, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0179)
# reconstruction difference between samples
# tensor(0.0382, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9377)
# reconstruction difference between samples
# tensor(0.0750, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4991)
# reconstruction difference between samples
# tensor(0.0249, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0149)
# reconstruction difference between samples
# tensor(0.0326, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9833)
# reconstruction difference between samples
# tensor(0.0413, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6802)
# reconstruction difference between samples
# tensor(0.0189, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9059)
# reconstruction difference between samples
# tensor(0.0740, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0022)
# reconstruction difference between samples
# tensor(0.0220, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3016)
# reconstruction difference between samples
# tensor(0.0353, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0807)
# reconstruction difference between samples
# tensor(0.0588, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4998)
# reconstruction difference between samples
# tensor(0.0396, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4220)
# reconstruction difference between samples
# tensor(0.0412, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4261)
# reconstruction difference between samples
# tensor(0.0607, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6438)
# reconstruction difference between samples
# tensor(0.0584, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5478)
# reconstruction difference between samples
# tensor(0.0442, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0677)
# reconstruction difference between samples
# tensor(0.0812, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6892)
# reconstruction difference between samples
# tensor(0.0841, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.2653)
# reconstruction difference between samples
# tensor(0.0915, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5335)
# reconstruction difference between samples
# tensor(0.0550, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6608)
# reconstruction difference between samples
# tensor(0.0636, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2913)
# reconstruction difference between samples
# tensor(0.0567, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6173)
# reconstruction difference between samples
# tensor(0.0814, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.6095)
# reconstruction difference between samples
# tensor(0.0496, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4585)
# reconstruction difference between samples
# tensor(0.0640, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3540)
# reconstruction difference between samples
# tensor(0.0561, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.7776)
# reconstruction difference between samples
# tensor(0.0514, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3343)
# reconstruction difference between samples
# tensor(0.0434, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1356)
# reconstruction difference between samples
# tensor(0.0617, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.3457)
# reconstruction difference between samples
# tensor(0.0557, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4823)
# reconstruction difference between samples
# tensor(0.0725, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3907)
# reconstruction difference between samples
# tensor(0.0190, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9450)
# reconstruction difference between samples
# tensor(0.0436, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8330)
# reconstruction difference between samples
# tensor(0.0414, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3898)
# reconstruction difference between samples
# tensor(0.0515, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.4365)
# reconstruction difference between samples
# tensor(0.0349, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.2642)
# reconstruction difference between samples
# tensor(0.0767, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.4981)
# reconstruction difference between samples
# tensor(0.0148, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1914)
# reconstruction difference between samples
# tensor(0.0697, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.6351)
# reconstruction difference between samples
# tensor(0.0465, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2778)
# reconstruction difference between samples
# tensor(0.0198, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(13.2463)
# reconstruction difference between samples
# tensor(0.1007, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.7309)
# reconstruction difference between samples
# tensor(0.0549, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3992)
# reconstruction difference between samples
# tensor(0.0361, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5308)
# reconstruction difference between samples
# tensor(0.0455, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2911)
# reconstruction difference between samples
# tensor(0.0542, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6276)
# reconstruction difference between samples
# tensor(0.0777, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.7335)
# reconstruction difference between samples
# tensor(0.0361, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2441)
# reconstruction difference between samples
# tensor(0.0640, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3906)
# reconstruction difference between samples
# tensor(0.0433, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6550)
# reconstruction difference between samples
# tensor(0.0375, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0526)
# reconstruction difference between samples
# tensor(0.0344, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0821)
# reconstruction difference between samples
# tensor(0.0867, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8568)
# reconstruction difference between samples
# tensor(0.0494, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0980)
# reconstruction difference between samples
# tensor(0.0628, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0526)
# reconstruction difference between samples
# tensor(0.0505, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.3467)
# reconstruction difference between samples
# tensor(0.0380, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4787)
# reconstruction difference between samples
# tensor(0.0524, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1401)
# reconstruction difference between samples
# tensor(0.0476, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8640)
# reconstruction difference between samples
# tensor(0.0567, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2620)
# reconstruction difference between samples
# tensor(0.0244, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0134)
# reconstruction difference between samples
# tensor(0.0429, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9615)
# reconstruction difference between samples
# tensor(0.0451, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9225)
# reconstruction difference between samples
# tensor(0.0214, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3059)
# reconstruction difference between samples
# tensor(0.0532, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.6937)
# reconstruction difference between samples
# tensor(0.0851, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2587)
# reconstruction difference between samples
# tensor(0.0494, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0735)
# reconstruction difference between samples
# tensor(0.0507, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5689)
# reconstruction difference between samples
# tensor(0.0454, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5530)
# reconstruction difference between samples
# tensor(0.0341, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9318)
# reconstruction difference between samples
# tensor(0.0437, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7105)
# reconstruction difference between samples
# tensor(0.0358, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4427)
# reconstruction difference between samples
# tensor(0.0437, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8001)
# reconstruction difference between samples
# tensor(0.0311, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8212)
# reconstruction difference between samples
# tensor(0.0579, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3708)
# reconstruction difference between samples
# tensor(0.0537, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.2330)
# reconstruction difference between samples
# tensor(0.0302, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(6.9601)
# reconstruction difference between samples
# tensor(0.0654, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0020)
# reconstruction difference between samples
# tensor(0.0328, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.6949)
# reconstruction difference between samples
# tensor(0.0596, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.0541)
# reconstruction difference between samples
# tensor(0.0535, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6069)
# reconstruction difference between samples
# tensor(0.0851, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8621)
# reconstruction difference between samples
# tensor(0.0511, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0066)
# reconstruction difference between samples
# tensor(0.0376, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3277)
# reconstruction difference between samples
# tensor(0.0405, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9284)
# reconstruction difference between samples
# tensor(0.0738, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2640)
# reconstruction difference between samples
# tensor(0.0442, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0903)
# reconstruction difference between samples
# tensor(0.0596, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5561)
# reconstruction difference between samples
# tensor(0.0657, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2779)
# reconstruction difference between samples
# tensor(0.0696, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4505)
# reconstruction difference between samples
# tensor(0.0363, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9497)
# reconstruction difference between samples
# tensor(0.0419, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3607)
# reconstruction difference between samples
# tensor(0.0551, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.2858)
# reconstruction difference between samples
# tensor(0.0480, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9411)
# reconstruction difference between samples
# tensor(0.0955, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8758)
# reconstruction difference between samples
# tensor(0.0996, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8756)
# reconstruction difference between samples
# tensor(0.0399, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.9471)
# reconstruction difference between samples
# tensor(0.1185, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.9834)
# reconstruction difference between samples
# tensor(0.0543, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3558)
# reconstruction difference between samples
# tensor(0.0276, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1132)
# reconstruction difference between samples
# tensor(0.0372, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.5365)
# reconstruction difference between samples
# tensor(0.0956, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7590)
# reconstruction difference between samples
# tensor(0.0514, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0013)
# reconstruction difference between samples
# tensor(0.0378, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0160)
# reconstruction difference between samples
# tensor(0.0377, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7609)
# reconstruction difference between samples
# tensor(0.0521, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.1863)
# reconstruction difference between samples
# tensor(0.0571, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5553)
# reconstruction difference between samples
# tensor(0.0378, grad_fn=<NormBackward0>)
# ...
# tensor(8.2904)
# reconstruction difference between samples
# tensor(0.0730, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(6.5273)
# reconstruction difference between samples
# tensor(0.0526, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.9992)
# reconstruction difference between samples
# tensor(0.0396, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1128)
# reconstruction difference between samples
# tensor(0.0818, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3900)
# reconstruction difference between samples
# tensor(0.0277, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6950)
# reconstruction difference between samples
# tensor(0.0411, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7608)
# reconstruction difference between samples
# tensor(0.0662, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4432)
# reconstruction difference between samples
# tensor(0.0731, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8558)
# reconstruction difference between samples
# tensor(0.0387, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0897)
# reconstruction difference between samples
# tensor(0.0758, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.4509)
# reconstruction difference between samples
# tensor(0.0205, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2611)
# reconstruction difference between samples
# tensor(0.0388, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4129)
# reconstruction difference between samples
# tensor(0.0503, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4329)
# reconstruction difference between samples
# tensor(0.0306, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4958)
# reconstruction difference between samples
# tensor(0.0549, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4853)
# reconstruction difference between samples
# tensor(0.0477, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8559)
# reconstruction difference between samples
# tensor(0.0395, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.8120)
# reconstruction difference between samples
# tensor(0.0602, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2897)
# reconstruction difference between samples
# tensor(0.0752, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.1354)
# reconstruction difference between samples
# tensor(0.0151, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1432)
# reconstruction difference between samples
# tensor(0.0473, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3828)
# reconstruction difference between samples
# tensor(0.0374, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2857)
# reconstruction difference between samples
# tensor(0.0842, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.0937)
# reconstruction difference between samples
# tensor(0.0547, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(6.1281)
# reconstruction difference between samples
# tensor(0.0257, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0725)
# reconstruction difference between samples
# tensor(0.0394, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3634)
# reconstruction difference between samples
# tensor(0.0513, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5516)
# reconstruction difference between samples
# tensor(0.0378, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.0700)
# reconstruction difference between samples
# tensor(0.0866, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.7803)
# reconstruction difference between samples
# tensor(0.0472, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9084)
# reconstruction difference between samples
# tensor(0.0245, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.3954)
# reconstruction difference between samples
# tensor(0.0311, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.5540)
# reconstruction difference between samples
# tensor(0.0987, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1769)
# reconstruction difference between samples
# tensor(0.0462, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1286)
# reconstruction difference between samples
# tensor(0.0413, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3098)
# reconstruction difference between samples
# tensor(0.0425, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5183)
# reconstruction difference between samples
# tensor(0.0494, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7794)
# reconstruction difference between samples
# tensor(0.0389, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(5.8039)
# reconstruction difference between samples
# tensor(0.0285, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.0874)
# reconstruction difference between samples
# tensor(0.0619, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0612)
# reconstruction difference between samples
# tensor(0.0633, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.0467)
# reconstruction difference between samples
# tensor(0.0335, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.8032)
# reconstruction difference between samples
# tensor(0.0392, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1715)
# reconstruction difference between samples
# tensor(0.0753, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8024)
# reconstruction difference between samples
# tensor(0.0418, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0351)
# reconstruction difference between samples
# tensor(0.0432, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7959)
# reconstruction difference between samples
# tensor(0.0715, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5655)
# reconstruction difference between samples
# tensor(0.0531, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3305)
# reconstruction difference between samples
# tensor(0.1165, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1579)
# reconstruction difference between samples
# tensor(0.0830, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4233)
# reconstruction difference between samples
# tensor(0.0517, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4673)
# reconstruction difference between samples
# tensor(0.0416, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0277)
# reconstruction difference between samples
# tensor(0.0561, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.7790)
# reconstruction difference between samples
# tensor(0.0379, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.1599)
# reconstruction difference between samples
# tensor(0.0517, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0489)
# reconstruction difference between samples
# tensor(0.0459, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7900)
# reconstruction difference between samples
# tensor(0.0508, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.2585)
# reconstruction difference between samples
# tensor(0.0493, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3997)
# reconstruction difference between samples
# tensor(0.0732, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.8262)
# reconstruction difference between samples
# tensor(0.0500, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6086)
# reconstruction difference between samples
# tensor(0.0350, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4756)
# reconstruction difference between samples
# tensor(0.0689, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.2106)
# reconstruction difference between samples
# tensor(0.0642, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8871)
# reconstruction difference between samples
# tensor(0.0453, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6630)
# reconstruction difference between samples
# tensor(0.0341, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7602)
# reconstruction difference between samples
# tensor(0.0557, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1775)
# reconstruction difference between samples
# tensor(0.0574, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6281)
# reconstruction difference between samples
# tensor(0.0664, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0924)
# reconstruction difference between samples
# tensor(0.0868, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6872)
# reconstruction difference between samples
# tensor(0.0579, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(6.2975)
# reconstruction difference between samples
# tensor(0.0183, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2787)
# reconstruction difference between samples
# tensor(0.0587, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.1225)
# reconstruction difference between samples
# tensor(0.0413, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5071)
# reconstruction difference between samples
# tensor(0.0303, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4015)
# reconstruction difference between samples
# tensor(0.0533, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.7094)
# reconstruction difference between samples
# tensor(0.0388, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6643)
# reconstruction difference between samples
# tensor(0.0675, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.7388)
# reconstruction difference between samples
# tensor(0.1279, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8298)
# reconstruction difference between samples
# tensor(0.0403, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2330)
# reconstruction difference between samples
# tensor(0.0458, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(6.8437)
# reconstruction difference between samples
# tensor(0.0455, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7349)
# reconstruction difference between samples
# tensor(0.0256, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6047)
# reconstruction difference between samples
# tensor(0.0555, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0482)
# reconstruction difference between samples
# tensor(0.0522, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.5763)
# reconstruction difference between samples
# tensor(0.0785, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4810)
# reconstruction difference between samples
# tensor(0.0176, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1724)
# reconstruction difference between samples
# tensor(0.0525, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.2866)
# reconstruction difference between samples
# tensor(0.0220, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.7306)
# reconstruction difference between samples
# tensor(0.1035, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.6166)
# reconstruction difference between samples
# tensor(0.0367, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0836)
# reconstruction difference between samples
# tensor(0.0304, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1602)
# reconstruction difference between samples
# tensor(0.0364, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8902)
# reconstruction difference between samples
# tensor(0.0367, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0193)
# reconstruction difference between samples
# tensor(0.0485, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4545)
# reconstruction difference between samples
# tensor(0.0664, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1520)
# reconstruction difference between samples
# tensor(0.0568, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4023)
# reconstruction difference between samples
# tensor(0.0544, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5306)
# reconstruction difference between samples
# tensor(0.0543, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.9476)
# reconstruction difference between samples
# tensor(0.0719, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6191)
# reconstruction difference between samples
# tensor(0.0527, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4635)
# reconstruction difference between samples
# tensor(0.0475, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3179)
# reconstruction difference between samples
# tensor(0.0514, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9971)
# reconstruction difference between samples
# tensor(0.0407, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1306)
# reconstruction difference between samples
# tensor(0.0577, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1407)
# reconstruction difference between samples
# tensor(0.0570, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.0372)
# reconstruction difference between samples
# tensor(0.0639, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5931)
# reconstruction difference between samples
# tensor(0.0590, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.2295)
# reconstruction difference between samples
# tensor(0.0831, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3445)
# reconstruction difference between samples
# tensor(0.0570, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2616)
# reconstruction difference between samples
# tensor(0.0496, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3171)
# reconstruction difference between samples
# tensor(0.0854, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9932)
# reconstruction difference between samples
# tensor(0.0590, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7987)
# reconstruction difference between samples
# tensor(0.0451, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.4325)
# reconstruction difference between samples
# tensor(0.0233, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2211)
# reconstruction difference between samples
# tensor(0.0547, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7801)
# reconstruction difference between samples
# tensor(0.0336, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0734)
# reconstruction difference between samples
# tensor(0.0737, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7292)
# reconstruction difference between samples
# tensor(0.0455, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.4455)
# reconstruction difference between samples
# tensor(0.0409, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5306)
# reconstruction difference between samples
# tensor(0.0301, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4451)
# reconstruction difference between samples
# tensor(0.0616, grad_fn=<NormBackward0>)

# %%
plt.imshow(recon_mnist[1,:].reshape(28,28).detach().numpy())

# %% [markdown]
# # Aligned VAE

# %%
class testDataset(Dataset):

    def __init__(self, batch):
        transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])
        train_dataset = torchvision.datasets.MNIST(
            root = './torch_dataset', train = True, download = True, transform = transform
        )
        # load training data and test data
        train_loader = torch.utils.data.DataLoader(
            dataset = train_dataset, batch_size = batch, shuffle = True, num_workers = 4, pin_memory = True
        )

        # subset first 512 images for training
        dataiter = iter(train_loader)
        images, labels = dataiter.next()

        mnist = images.squeeze().reshape(batch, 28*28)
        print(mnist.shape)

        self.expr_ATAC = mnist[:int(batch/2),:]
        self.expr_RNA = mnist[int(batch/2):,:]



        # self.transform = transform
        self.expr_ATAC = torch.FloatTensor(mnist)
        self.expr_RNA = torch.FloatTensor(mnist)
        print(self.expr_ATAC.shape)
        print(self.expr_RNA.shape)
        
    def __len__(self):
        # number of cells
        return len(self.expr_ATAC)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        # index denote the index of the cell
        sample = {'ATAC': self.expr_ATAC[idx,:], 'RNA':self.expr_RNA[idx,:], 'index':idx}
        
        # if self.transform:
        #     sample = self.transform(sample)
        
        return sample

# %%
def dist_loss_kl(recon_atac, recon_rna, atac, rna, z, diff_atac, diff_rna, logvarz, muz, lamb, dist_loss_type = "cosine", beta=0.01):

    # Checked dimesion correct
    loss_recon_rna = F.mse_loss(rna, recon_rna)
    loss_recon_atac = F.mse_loss(atac, recon_atac)

    # only one 
    loss_recon_atac = torch.tensor(0)
    # loss_recon_rna = 0
    # cosine similarity loss, don't forget to normalize the matrix before calculate inner product
    if dist_loss_type == "cosine":
        # diff_atac and diff_rna are only constant, but better to be normalized
        Sim = pairwise_distance(z)
        # normalize latent similarity matrix
        Sim = Sim / torch.norm(Sim, p='fro')

        # inner product loss, maximize, so add negative before, in addition, make sure those two values are normalized, with norm 1
        loss_dist_atac = - lamb * torch.sum(diff_atac * Sim)
        loss_dist_rna = - lamb * torch.sum(diff_rna * Sim)

    # pearson correlationship
    elif dist_loss_type == "pearson":
        Sim = pairwise_distance(z)
        Vs = Sim - torch.mean(Sim)

        Vd_atac = diff_atac - torch.mean(diff_atac)
        Vd_rna = diff_rna - torch.mean(diff_rna)

        # maximize correlationship
        loss_dist_atac = - lamb * torch.sum(Vs * Vd_atac) / (torch.sqrt(torch.sum(Vs ** 2)) * torch.sqrt(torch.sum(Vd_atac ** 2)))
        loss_dist_rna = - lamb * torch.sum(Vs * Vd_rna) / (torch.sqrt(torch.sum(Vs ** 2)) * torch.sqrt(torch.sum(Vd_rna ** 2)))
    
    # mse loss
    elif dist_loss_type == "mse":
        loss_dist_atac = lamb * F.mse_loss(diff_atac.reshape(-1), pairwise_distance(z).reshape(-1))
        loss_dist_rna = lamb * F.mse_loss(diff_rna.reshape(-1), pairwise_distance(z).reshape(-1))
    
    # No distance loss
    else:
        loss_dist_atac = torch.tensor(0)
        loss_dist_rna = torch.tensor(0)

    loss_kl = beta * 0.5 * torch.sum(- logvarz + torch.exp(logvarz) + muz * muz - 1)

    loss = loss_recon_rna + loss_recon_atac + loss_dist_atac + loss_dist_rna + loss_kl
    return loss, loss_recon_rna, loss_recon_atac,  loss_dist_atac,  loss_dist_rna, loss_kl

# %%
def train_vae(model, data_loader, lamb = 1, beta = 0.01, similarity = "DPT", dist_loss_type = 'cosine'):
    model.train()

    total_loss = 0
    total_loss_recon_rna = total_loss_recon_atac = 0
    total_loss_dist_atac = total_loss_dist_rna = 0
    total_loss_kl = 0
    for data in data_loader:
        optimizer.zero_grad()
        batch_atac = data['ATAC'].to(device)
        batch_rna = data['RNA'].to(device)
        recon_atac, recon_rna, z, logvarz, muz = model(batch_atac, batch_rna)

        if similarity == "DPT":
            batch_diff_atac = DPT_atac[data['index'], :][:, data['index']]
            batch_diff_rna = DPT_rna[data['index'], :][:, data['index']]           
        
        elif similarity == "diffusion map":
            batch_diff_atac = diff_sim_atac[data['index'], :][:, data['index']]
            batch_diff_rna = diff_sim_rna[data['index'], :][:, data['index']]
        
        # No similarity
        else:
            batch_diff_atac = 0
            batch_diff_rna = 0
            dist_loss_type = 'None'


        loss = dist_loss_kl(recon_atac, recon_rna, batch_atac, batch_rna, z, batch_diff_atac, batch_diff_rna, logvarz, muz, lamb = lamb, dist_loss_type= dist_loss_type, beta = beta)
        total_loss += loss[0]
        total_loss_recon_rna += loss[1]
        total_loss_recon_atac += loss[2]
        total_loss_dist_rna += loss[3]
        total_loss_dist_atac += loss[4]
        total_loss_kl += loss[5]
        current_loss = loss[0]
        current_loss.backward()
        optimizer.step()
    
    scalar = data_loader.batch_size / 512
    return total_loss.item() * scalar, total_loss_recon_rna.item() * scalar, total_loss_recon_atac.item() * scalar, \
 total_loss_dist_rna.item() * scalar, total_loss_dist_atac.item() * scalar, total_loss_kl.item() * scalar

# %%
def test_vae(model, data_loader):
    model.eval()
    # model.train()
    for count, data in enumerate(data_loader):
        print("test", count)
        recon_atac, recon_rna, z, logvarz, muz = model(torch.FloatTensor(data['ATAC']).to(device), data['RNA'].to(device))

        # in evaluation mode z = muz
        z = z.detach().cpu().numpy()
        
        print("ATAC reconstruction loss", F.mse_loss(data['ATAC'].to(device), recon_atac).item())
        print("RNA reconstruction loss", F.mse_loss(data['RNA'].to(device), recon_rna).item())
        # print(data['ATAC'])
        print("RNA")
        # print(torch.unique(data['RNA'],dim = 1))
        
        for j in np.arange(data['RNA'].shape[0]):
            print("original difference between sample")
            print(torch.norm(data['RNA'][0,:] - data['RNA'][j,:]))
            print("reconstruction difference between samples")
            print(torch.norm(recon_rna[0,:] - recon_rna[j,:]))

        print()
        print("z")
        print(z)

    return z, recon_atac, recon_rna

# %%
batch = 1024
test_mnist = testDataset(batch)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# torch.Size([1024, 784])
# torch.Size([1024, 784])
# torch.Size([1024, 784])

# %%
len(test_mnist)
# Out:
# 1024

# %%
train_loader = DataLoader(test_mnist, shuffle=True, batch_size=32)
test_loader = DataLoader(test_mnist, shuffle = False, batch_size=batch)

model_vae = aligned_vae(in_channels_atac=28*28, in_channels_rna=28*28, latent_channels_atac=4, latent_channels_rna=4, latent_channels_z=2, layer1_channels= 32, layer2_channels=16).to(device)
optimizer = torch.optim.Adam(model_vae.parameters(), lr=1e-4, weight_decay=0.01)

for epoch in range(0, 151):

    loss, l1, l2, l3, l4, l5 = train_vae(model = model_vae, data_loader = train_loader, lamb = 100, beta=0.01, similarity = "None")
    if epoch % 10 == 0:
        log = "Epoch: {:03d}, Total loss: {:.5f}, Recon RNA loss: {:.5f}, Recon ATAC loss {:.5f}, Dist RNA loss {:.5f}, Dist ATAC loss {:.5f}, KL loss: {:.5f}"
        print(log.format(epoch, loss, l1, l2, l3, l4, l5))
# Out:
# Epoch: 000, Total loss: 0.38828, Recon RNA loss: 0.26600, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.12228
# Epoch: 010, Total loss: 0.33350, Recon RNA loss: 0.23094, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.10256
# Epoch: 020, Total loss: 0.30044, Recon RNA loss: 0.21515, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.08529
# Epoch: 030, Total loss: 0.27384, Recon RNA loss: 0.20388, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.06995
# Epoch: 040, Total loss: 0.25061, Recon RNA loss: 0.19414, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.05647
# Epoch: 050, Total loss: 0.22995, Recon RNA loss: 0.18511, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.04484
# Epoch: 060, Total loss: 0.21233, Recon RNA loss: 0.17734, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.03499
# Epoch: 070, Total loss: 0.19776, Recon RNA loss: 0.17094, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.02683
# Epoch: 080, Total loss: 0.18609, Recon RNA loss: 0.16590, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.02019
# Epoch: 090, Total loss: 0.17774, Recon RNA loss: 0.16285, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.01490
# Epoch: 100, Total loss: 0.17170, Recon RNA loss: 0.16093, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.01077
# Epoch: 110, Total loss: 0.16733, Recon RNA loss: 0.15972, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.00760
# Epoch: 120, Total loss: 0.16411, Recon RNA loss: 0.15890, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.00521
# Epoch: 130, Total loss: 0.16204, Recon RNA loss: 0.15860, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.00344
# Epoch: 140, Total loss: 0.16090, Recon RNA loss: 0.15872, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.00218
# Epoch: 150, Total loss: 0.16024, Recon RNA loss: 0.15892, Recon ATAC loss 0.00000, Dist RNA loss 0.00000, Dist ATAC loss 0.00000, KL loss: 0.00132

# %%
z, recon_atac, recon_rna = test_vae(model_vae, test_loader)
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot()
ax.scatter(z[:,0], z[:,1])
# Out:
# test 0
# ATAC reconstruction loss 0.1315058171749115
# RNA reconstruction loss 0.08010965585708618
# RNA
# original difference between sample
# tensor(0.)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2906)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4801)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3730)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3132)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4810)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1087)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8549)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7690)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0430)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5099)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8646)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2553)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4957)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0156)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4105)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.7215)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4860)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9896)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.9024)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1094)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0769)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9236)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8590)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3028)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5546)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6250)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7727)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9168)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.9165)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6527)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1168)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7034)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.9567)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4649)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.9138)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6099)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4084)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3698)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4776)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0000)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7406)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9420)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4302)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2847)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4739)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5737)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1368)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5033)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1350)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8055)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9722)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1387)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4971)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5253)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3181)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3160)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5290)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.9574)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.0920)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1965)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3343)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7715)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2209)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0270)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4918)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.0066)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5563)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3041)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3513)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9504)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5079)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1777)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6678)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.6754)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8702)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6179)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3019)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1233)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7010)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.6643)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8271)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5639)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2007)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.2903)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6201)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5198)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4030)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1304)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2048)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7806)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2609)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7424)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8830)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3904)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8912)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1566)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.6737)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9808)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0978)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1959)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1775)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3564)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6739)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6984)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3105)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7887)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.6994)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4153)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7245)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1019)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1313)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0493)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1825)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3706)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5910)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5733)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8497)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0133)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1638)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.2315)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8818)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3866)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4442)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2393)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8264)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7069)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3165)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0479)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9741)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3432)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3300)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7036)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.8404)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5113)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3239)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7852)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8073)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.3556)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9420)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3020)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6459)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1406)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7973)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0785)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8479)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1513)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7451)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9859)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.7443)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1666)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2485)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0461)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0583)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1474)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3171)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1276)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9320)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1388)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6234)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0234)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1026)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3290)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0433)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4610)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4809)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6031)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0821)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5477)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6510)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8081)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5145)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3737)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0841)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0494)
# reconstruction difference between samples
# tensor(6.2988e-08, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4433)
# reconstruction difference between samples
# tensor(6.2988e-08, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8242)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2472)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9716)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5772)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0442)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9308)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7120)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0044)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8953)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8493)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.7165)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.1062)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5143)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.8241)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0586)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0388)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8631)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9008)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2393)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5467)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8827)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7268)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1818)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5709)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.5608)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7310)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1100)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1726)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1663)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6680)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0955)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9091)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5410)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1099)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.2134)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5996)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4578)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7677)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3119)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4117)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6311)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9393)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6047)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.6421)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0352)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6251)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0537)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1034)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8571)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2223)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1858)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6646)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.4391)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8665)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2421)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6884)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4842)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0602)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5942)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7225)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4255)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2081)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8868)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5594)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0441)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6683)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5138)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7900)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3877)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7611)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0659)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1851)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7839)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1518)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6017)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4377)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8132)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.8351)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8738)
# reconstruction difference between samples
# tensor(6.2988e-08, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.5791)
# reconstruction difference between samples
# tensor(6.2988e-08, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7945)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4824)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7479)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6919)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4272)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8113)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2539)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2950)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.8991)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.4751)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9655)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1717)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9495)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8721)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5713)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9258)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4403)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3368)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1036)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0844)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6224)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.5928)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1572)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.7770)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5595)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4973)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2218)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0424)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1037)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6574)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9977)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5445)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5638)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9637)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0618)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0191)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1362)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5373)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1626)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4382)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2861)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6018)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0598)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6820)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7881)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3542)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0244)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0306)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3796)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9817)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4066)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0586)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5726)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7210)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5340)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5835)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5669)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9537)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5926)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1790)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.4603)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8862)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8956)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8680)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0216)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.6865)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9402)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9003)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1980)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5901)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5764)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1988)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6166)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1190)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5640)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5337)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2092)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5503)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3046)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7523)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5600)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8171)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3509)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0463)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2499)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7514)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3998)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0623)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6964)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4776)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6343)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0909)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1773)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7613)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6767)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9226)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5571)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7674)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1259)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0280)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1242)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8470)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8680)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4105)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1539)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3815)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5013)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1746)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0498)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2741)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7889)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7188)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6703)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0949)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8729)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4317)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# ...
# tensor(10.0368)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4063)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9240)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3485)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1486)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5075)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2218)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1550)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3845)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1886)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4116)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.1150)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5437)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.2333)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4224)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0365)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6838)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3432)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5667)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4504)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9305)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1711)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.6996)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5014)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4706)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7868)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4333)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4707)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0223)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.7548)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2113)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.2743)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0054)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9075)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5675)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5603)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.5652)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7184)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.8641)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5008)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8840)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(7.4230)
# reconstruction difference between samples
# tensor(6.2988e-08, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2563)
# reconstruction difference between samples
# tensor(6.2988e-08, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0044)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1759)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1161)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1699)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5073)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.0806)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6905)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9878)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0969)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1170)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2528)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.6414)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4489)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5327)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2607)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7728)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8208)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3297)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.8924)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5324)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9585)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2445)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3664)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9426)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3609)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5610)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7092)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5506)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3575)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3602)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1582)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6147)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1289)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.9572)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6843)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.8712)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5651)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8886)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9702)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7662)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.5255)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.4581)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9025)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.3263)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.2698)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0802)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6683)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.9793)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6193)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.1097)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.2556)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7729)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.0264)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.7538)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.5706)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.2394)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1740)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6348)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.6766)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.9833)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(12.4881)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.0088)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6707)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6500)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.8249)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8529)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3980)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.6582)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.5595)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.7252)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1117)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.3075)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.1241)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.1387)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.3195)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(8.7965)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.4805)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(11.4633)
# reconstruction difference between samples
# tensor(0., grad_fn=<NormBackward0>)
# original difference between sample
# tensor(10.1916)
# reconstruction difference between samples
# tensor(6.2988e-08, grad_fn=<NormBackward0>)
# original difference between sample
# tensor(9.8645)
# reconstruction difference between samples
# tensor(6.2988e-08, grad_fn=<NormBackward0>)
#
# z
# [[-0.04068299  0.04035453]
#  [-0.04068299  0.04035453]
#  [-0.04068299  0.04035453]
#  ...
#  [-0.04068299  0.04035453]
#  [-0.04068299  0.04035453]
#  [-0.04068299  0.04035453]]

# %%
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot()
ax.scatter(z[:,0], z[:,1])

# %%
plt.imshow(recon_rna[3,:].reshape(28,28).detach().numpy())

# %%
plt.imshow(recon_atac[3,:].reshape(28,28).detach().numpy())
